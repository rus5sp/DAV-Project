# %%
import pandas as pd

# %%
economy_dfs = [
    birth_rate, employed_population, gdp_per_capita, 
    monthly_salaries, unemployment_rate,
    ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 economy_dfs = [
# ----> 2     birth_rate, employed_population, gdp_per_capita,
#       3     monthly_salaries, unemployment_rate,
#       4     ]
#
# NameError: name 'birth_rate' is not defined

# %%
df = pd.read_excel("data/raw/economy/birth_rate.xlsx")
df
# Out:
#                                   Төрөлгөндөрдүн саны  \
# 0                                              (адам)
# 1                                                 NaN
# 2                          Көрсөткүчтөрдүн аталыштары
# 3                                 Кыргыз Республикасы
# 4                                       Баткен облусу
# 5                                   Жалал-Абад облусу
# 6                                     Ысык-Көл облусу
# 7                                        Нарын облусу
# 8                                           Ош облусу
# 9                                        Талас облусу
# 10                                        Чүй облусу
# 11                                          Бишкек ш.
# 12                                              Ош ш.
# 13  1 Кыргыз Республикасындагы административдик-ай...
#
#                                      Число родившихся  \
# 0                                           (человек)
# ...
